# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Litecoin and create a DataFrame of sentiment scores for each coin.

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mrnagleJR97/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_headlines = newsapi.get_everything(
    q="bitcoin",
    language="en",
    sort_by="relevancy"
)

# %%
# Fetch the Litecoin news articles
lite_headlines = newsapi.get_everything(
    q="litecoin",
    language="en",
    sort_by="relevancy"
)

# %%
# Create the Bitcoin sentiment scores DataFrame
sentiments = []

for articles in btc_headlines["articles"]:
    try:
        text = articles["content"]
        results = analyzer.polarity_scores(text)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text,
        })
    except AttributeError:
        pass
    
btc = pd.DataFrame(sentiments)
btc.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.4215     0.098       0.0    0.902
# 1    0.1779     0.052       0.0    0.948
# 2    0.1280     0.046       0.0    0.954
# 3    0.6187     0.153       0.0    0.847
# 4    0.6908     0.161       0.0    0.839
#
#                                                 text
# 0  PayPal will now allow users outside the U.S. t...
# 1  A recently-installed Bitcoin ATM.\r\n\n \n\n A...
# 2  The government of El Salvador purchased at lea...
# 3  Retailers are increasingly accepting cryptocur...
# 4  PayPal is bringing the ability to buy, hold an...

# %%
# Create the Litecoin sentiment scores DataFrame
sentiments = []

for articles in lite_headlines["articles"]:
    try:
        text = articles["content"]
        results = analyzer.polarity_scores(text)
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        
        sentiments.append({
            "Compound": compound,
            "Positive": pos,
            "Negative": neg,
            "Neutral": neu,
            "text": text,
        })
    except AttributeError:
        pass
    
lite = pd.DataFrame(sentiments)
lite.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.4215     0.098       0.0    0.902
# 1    0.6908     0.161       0.0    0.839
# 2    0.4215     0.095       0.0    0.905
# 3    0.2263     0.094       0.0    0.906
# 4    0.5106     0.137       0.0    0.863
#
#                                                 text
# 0  PayPal will now allow users outside the U.S. t...
# 1  PayPal is bringing the ability to buy, hold an...
# 2  PayPal is to allow users in the UK to buy, hol...
# 3  PayPal launched its crypto services in the UKi...
# 4  Andrew Kelly/Reuters\r\n<ul><li>Bitcoin and et...

# %%
# Describe the Bitcoin Sentiment
btc.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.127405   0.064100   0.035000   0.900900
# std     0.397865   0.048757   0.067033   0.062279
# min    -0.886000   0.000000   0.000000   0.729000
# 25%     0.000000   0.044000   0.000000   0.869250
# 50%     0.128000   0.050500   0.000000   0.904500
# 75%     0.421500   0.095250   0.045750   0.948750
# max     0.690800   0.161000   0.271000   1.000000

# %%
# Describe the Litecoin Sentiment
lite.describe()
# Out:
#         Compound   Positive   Negative    Neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.182960   0.072950   0.026400   0.900650
# std     0.401595   0.068742   0.072363   0.081379
# min    -0.893400   0.000000   0.000000   0.688000
# 25%     0.000000   0.000000   0.000000   0.842000
# 50%     0.226300   0.078500   0.000000   0.905500
# 75%     0.516600   0.142250   0.000000   0.959500
# max     0.700300   0.182000   0.312000   1.000000

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
#
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
wnl = WordNetLemmatizer()

# Create a list of stopwords
stop = stopwords.words("english")

# Expand the default stopwords list if necessary
stop.append("u")
stop.append("it'")
stop.append("'s")
stop.append("n't")
stop.append('...')
stop.append("\`")
stop.append('``')
stop.append('char')
stop.append("''")
stop = set(stop)

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a tokenized list of the words
    words = word_tokenize(text)
    
    
    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    
    
    # Remove the stop words
    words = list(filter(lambda t: t.lower() not in stop, words))
    
    # Lemmatize words into root words
    tokens = [wnl.lemmatize(word) for word in words]
   
    return tokens

# %%
# Create a new tokens column for Bitcoin
btc["tokens"] = btc.text.apply(tokenizer)
btc.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.4215     0.098       0.0    0.902
# 1    0.1779     0.052       0.0    0.948
# 2    0.1280     0.046       0.0    0.954
# 3    0.6187     0.153       0.0    0.847
# 4    0.6908     0.161       0.0    0.839
#
#                                                 text  \
# 0  PayPal will now allow users outside the U.S. t...
# 1  A recently-installed Bitcoin ATM.\r\n\n \n\n A...
# 2  The government of El Salvador purchased at lea...
# 3  Retailers are increasingly accepting cryptocur...
# 4  PayPal is bringing the ability to buy, hold an...
#
#                                               tokens
# 0  [PayPal, allow, user, outside, U.S., buy, hold...
# 1  [recently-installed, Bitcoin, ATM, today, Bitc...
# 2  [government, El, Salvador, purchased, least, 2...
# 3  [Retailers, increasingly, accepting, cryptocur...
# 4  [PayPal, bringing, ability, buy, hold, sell, c...

# %%
# Create a new tokens column for Ethereum
lite["tokens"] = lite.text.apply(tokenizer)
lite.head()
# Out:
#    Compound  Positive  Negative  Neutral  \
# 0    0.4215     0.098       0.0    0.902
# 1    0.6908     0.161       0.0    0.839
# 2    0.4215     0.095       0.0    0.905
# 3    0.2263     0.094       0.0    0.906
# 4    0.5106     0.137       0.0    0.863
#
#                                                 text  \
# 0  PayPal will now allow users outside the U.S. t...
# 1  PayPal is bringing the ability to buy, hold an...
# 2  PayPal is to allow users in the UK to buy, hol...
# 3  PayPal launched its crypto services in the UKi...
# 4  Andrew Kelly/Reuters\r\n<ul><li>Bitcoin and et...
#
#                                               tokens
# 0  [PayPal, allow, user, outside, U.S., buy, hold...
# 1  [PayPal, bringing, ability, buy, hold, sell, c...
# 2  [PayPal, allow, user, UK, buy, hold, sell, cry...
# 3  [PayPal, launched, crypto, service, UKits, fir...
# 4  [Andrew, Kelly/Reuters, ul, li, Bitcoin, ether...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
N = 2
grams = ngrams(tokenizer(btc.text.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('El', 'Salvador'), 7),
#  (('buy', 'hold'), 3),
#  (('hold', 'sell'), 3),
#  (('Central', 'American'), 3),
#  (('American', 'country'), 3),
#  (('became', 'first'), 3),
#  (('PayPal', 'allow'), 2),
#  (('allow', 'user'), 2),
#  (('first', 'time'), 2),
#  (('allow', 'customer'), 2),
#  (('char', 'PayPal'), 2),
#  (('sell', 'cryptocurrencies'), 2),
#  (('char', 'Joe'), 2),
#  (('Joe', 'TidyCyber'), 2),
#  (('TidyCyber', 'reporter'), 2),
#  (('New', 'York'), 2),
#  (('Photo/File', 'Photo/File'), 2),
#  (('char', 'Posted'), 2),
#  (('Posted', 'El'), 2),
#  (('El', 'Zonte'), 2)]

# %%
# Generate the Ethereum N-grams where N=2
N = 2
grams = ngrams(tokenizer(lite.text.str.cat()), N)
Counter(grams).most_common(20)
# Out:
# [(('buy', 'hold'), 4),
#  (('hold', 'sell'), 4),
#  (('PC', 'motherboard'), 4),
#  (('motherboard', 'illustration'), 4),
#  (('illustration', 'taken'), 4),
#  (('2021', 'REUTERS/Dado'), 4),
#  (('first', 'time'), 3),
#  (('char', 'PayPal'), 3),
#  (('char', 'Representations'), 3),
#  (('Representations', 'cryptocurrencies'), 3),
#  (('cryptocurrencies', 'Bitcoin'), 3),
#  (('Bitcoin', 'Ethereum'), 3),
#  (('placed', 'PC'), 3),
#  (('taken', 'June'), 3),
#  (('June', '29'), 3),
#  (('29', '2021'), 3),
#  (('Finance', 'Insider'), 3),
#  (('Insider', 'writes'), 3),
#  (('writes', 'product'), 3),
#  (('product', 'strategy'), 3)]

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
all_tokens = tokenizer(btc.text.str.cat())
token_count(all_tokens, 10)
# Out:
# [('char', 18),
#  ('cryptocurrency', 10),
#  ('El', 10),
#  ('bitcoin', 9),
#  ('Salvador', 8),
#  ('first', 7),
#  ('Bitcoin', 6),
#  ('country', 6),
#  ('allow', 4),
#  ('hold', 4)]

# %%
# Use token_count to get the top 10 words for Ethereum
all_tokens = tokenizer(lite.text.str.cat())
token_count(all_tokens, 10)
# Out:
# [('char', 19),
#  ('Bitcoin', 9),
#  ('PayPal', 8),
#  ('cryptocurrency', 6),
#  ('…', 6),
#  ('2021', 6),
#  ('allow', 5),
#  ('cryptocurrencies', 5),
#  ('illustration', 5),
#  ('taken', 5)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
def wordcloud(text, title=""):
    df_cloud = WordCloud(width=500, colormap='RdYlBu').generate(text)
    plt.imshow(df_cloud)
    plt.axis("off")
    fontdict = {"fontsize": 48, "fontweight" : "bold"}
    plt.title(title, fontdict=fontdict)
    plt.show()

# %%
wordcloud(btc.text.str.cat(), title="Bitcoin Word Cloud")

# %%
# Generate the Ethereum word cloud
wordcloud(lite.text.str.cat(), title="Litecoin Word Cloud")

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
all_btc_text = btc.text.str.cat()
all_btc_text
# Out:
# 'PayPal will now allow users outside the U.S. to buy, hold and sell cryptocurrency for the first time. The company announced today the launch of a new service that will allow customers in the U.K. to … [+4420 chars]A recently-installed Bitcoin ATM.\r\n\n \n\n As of today, Bitcoin is an official currency of El Salvador alongside the US dollar, after the Central American country became the first to adopt the cryptocur… [+2716 chars]The government of El Salvador purchased at least 200 bitcoin recently, ahead of the country officially recognizing bitcoin as a form of legal currency on Tuesday. The purchase brings the governments … [+3142 chars]Retailers are increasingly accepting cryptocurrency for physical items, but did you know\xa0you can spend crypto on ephemeral experiences like travel too? As more cryptocurrency holders indicate a willi… [+2783 chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of a year after it launched in the US. In a statement, the company said tha… [+850 chars]By Joe TidyCyber reporter \r\n"Follow the money" - for generations it\'s been the mantra of investigators looking for criminals.\r\nIn the cyber-realm, this battle between criminals and the authorities ha… [+3786 chars]By Joe TidyCyber reporter \r\nTaxi driver Chris is obsessively checking his phone for updates.\r\n"I\'m set to lose almost 2,500 euros (£2,100) worth of cryptocurrency coins," he says.\r\nChris describes hi… [+6584 chars]New York (CNN Business)It\'s a volatile day for bitcoin, which briefly fell by about 10% Tuesday below the $43,000 mark.\r\nThe drop comes after El Salvador made good on a plan announced in June and ado… [+1279 chars]8. Were just days into September, and its time to start thinking about your spring garden.\r\nRather than following the common practice of planting and transplanting in spring, Rebecca McMackin, the di… [+494 chars]A representation of cryptocurrency Bitcoin is seen in this illustration taken August 6, 2021. REUTERS/Dado Ruvic/Illustration/File Photo/File Photo/File Photo/File PhotoSept 7 (Reuters) - Fintech Bit… [+1978 chars]After the bell today, Coinbase reported another period of impressive results in its second quarter earnings report.\r\nDuring the quarter, Coinbase’s total revenue reached $2.23 billion, which helped t… [+4900 chars]PayPal is to allow users in the UK to buy, hold and sell cryptocurrencies through the payment platform for the first time.\r\nThe firm said it would allow customers to choose from four types of cryptoc… [+3160 chars]T-Mobile will offer two years of free identity theft protection services after hackers stole data on roughly 49 million customers and potential customers, according to a statement from the mobile car… [+2971 chars]Posted \r\nEl Zonte, El Salvador, home to \'Bitcoin Beach,\' is looking to ride the cryptocurrency wave as bitcoin becomes legal tender in the Central American country. Conway G. Gittens reports.Aug 27 (Reuters) - The first cryptocurrency ATM in Honduras opened this week as bitcoin backers sought to spur demand for virtual assets after neighboring El Salvador became the first country to esta… [+1733 chars]Aug 27 (Reuters) - The first cryptocurrency ATM in Honduras opened this week as bitcoin backers sought to spur demand for virtual assets after neighboring El Salvador became the first country to esta… [+1669 chars]Posted \r\nEl Zonte, El Salvador, home to \'Bitcoin Beach,\' is looking to ride the cryptocurrency wave as bitcoin becomes legal tender in the Central American country. Conway G. Gittens reports.Twitter\'s latest beta update introduces support for providing content creators with Bitcoin tips using the "Tip Jar" feature that Twitter introduced earlier this year. Bitcoin isn\'t yet available to … [+1516 chars]Bitcoin plunged as much as 17 per cent to its lowest level in a month as El Salvadors crypto rollout got off to a rocky start.\xa0\r\nThe largest cryptocurr ...

# %%
# Run the NER processor on all of the text
doc = nlp(all_btc_text)

# Add a title to the document
doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will now allow users outside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to buy, hold and sell cryptocurrency for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time. The company announced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the launch of a new service that will allow customers in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to … [+4420 chars]A recently-installed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin ATM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> </br></br> As of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Bitcoin is an official currency of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  alongside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  dollar, after the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  country became the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  to adopt the cryptocur… [+2716 chars]The government of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  purchased
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least 200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bitcoin recently, ahead of the country officially recognizing bitcoin as a form of legal currency on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The purchase brings the governments … [+3142 chars]Retailers are increasingly accepting cryptocurrency for physical items, but did you know you can spend crypto on ephemeral experiences like travel too? As more cryptocurrency holders indicate a willi… [+2783 chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after it launched in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In a statement, the company said tha… [+850 chars]By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe TidyCyber
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>In the cyber-realm, this battle between criminals and the authorities ha… [+3786 chars]By
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Joe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TidyCyber reporter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>Taxi driver
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>&quot;I'm set to lose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     almost 2,500
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  euros (£
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2,100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# PayPal ORG
# U.S. GPE
# first ORDINAL
# today DATE
# U.K. GPE
# Bitcoin ATM ORG
# today DATE
# El Salvador GPE
# US GPE
# Central American NORP
# first ORDINAL
# El Salvador GPE
# at least 200 CARDINAL
# Tuesday DATE
# a year DATE
# US GPE
# Joe TidyCyber PERSON
# Joe PERSON
# TidyCyber reporter MONEY
# Chris PERSON
# almost 2,500 CARDINAL
# 2,100 MONEY
# Chris PERSON
# chars]New York GPE
# CNN ORG
# a volatile day DATE
# about 10% PERCENT
# Tuesday DATE
# $43,000 mark MONEY
# El Salvador GPE
# June DATE
# chars]8 ORG
# just days DATE
# September DATE
# spring DATE
# Rebecca McMackin PERSON
# August 6, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration/File Photo/File Photo/File Photo/File PhotoSept 7 ORG
# Reuters ORG
# today DATE
# Coinbase PERSON
# its second quarter DATE
# the quarter DATE
# Coinbase ORG
# $2.23 billion MONEY
# UK GPE
# first ORDINAL
# four CARDINAL
# chars]T-Mobile ORG
# two years DATE
# roughly 49 million CARDINAL
# El Zonte GPE
# El Salvador GPE
# Bitcoin Beach GPE
# Central American NORP
# Conway G. Gittens PERSON
# 27 CARDINAL
# Reuters ORG
# first ORDINAL
# ATM ORG
# Honduras GPE
# this week DATE
# El Salvador GPE
# first ORDINAL
# 27 CARDINAL
# Reuters ORG
# first ORDINAL
# ATM ORG
# Honduras GPE
# this week DATE
# El Salvador GPE
# first ORDINAL
# El Zonte GPE
# El Salvador GPE
# Bitcoin Beach GPE
# Central American NORP
# Conway G. Gittens PERSON
# Twitter PERSON
# Tip Jar WORK_OF_ART
# Twitter PERSON
# earlier this year DATE
# as much as 17 CARDINAL
# a month DATE
# El Salvadors NORP
# as low as US$43,050 MONEY
# New York Tuesda GPE
# +4328 PERSON
# as much as 17 CARDINAL
# US$43,050
#  MONEY
# San Salvador GPE
# Sept. 7 DATE
# 2021.Photo CARDINAL
# Ma PERSON

# %% [markdown]
# ---

# %% [markdown]
# ### Litecoin NER

# %%
# Concatenate all of the Ethereum text together
all_lite_text = lite.text.str.cat()
all_lite_text
# Out:
# "PayPal will now allow users outside the U.S. to buy, hold and sell cryptocurrency for the first time. The company announced today the launch of a new service that will allow customers in the U.K. to … [+4420 chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of a year after it launched in the US. In a statement, the company said tha… [+850 chars]PayPal is to allow users in the UK to buy, hold and sell cryptocurrencies through the payment platform for the first time.\r\nThe firm said it would allow customers to choose from four types of cryptoc… [+3160 chars]PayPal\xa0launched its crypto services in the UKits first international crypto expansion, according to a press release.\r\nPayPal's total payment volume reached $311 billion in Q2 2021.\r\nInsider Intellige… [+2125 chars]Andrew Kelly/Reuters\r\n<ul><li>Bitcoin and ether plummeted on Tuesday, the same day El Salvador adopted the crypto as legal tender.</li><li>The popular cryptocurrency fell from a high of about $52,000… [+1835 chars]Representations of cryptocurrencies Bitcoin and Ethereum are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/IllustrationAug 10 (Reuters) - Paypal Holdings Inc-… [+991 chars]By Reuters Staff\r\nRepresentations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken June 29, 2021. REUTERS/Dado Ruvic/Illustrat… [+1168 chars]A smartphone with the PayPal logo is placed on a laptop in this illustration taken on July 14, 2021. REUTERS/Dado Ruvic/IllustrationLONDON, Aug 23 (Reuters) - PayPal Holdings Inc (PYPL.O) will allow … [+1901 chars]Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+6018 chars]August\r\n23, 2021\r\n2 min read\r\nAfter a months-long slump, Bitcoin finally surged above $50,000 Sunday night for the first time since mid-May.\xa0\r\nBitcoin saw smaller surges in that time. At the end of J… [+1234 chars]Coinbase and Bitcoin\r\nSOPA images\r\nCoinbase fell as much as 6% on Tuesday amid an ongoing service outage that led to crypto transactions being delayed or canceled.\r\nThe outage, according to Coinbase,… [+1089 chars]Its the weirdest cryptocurrency heist so far. On Monday, Poly Network, a cryptocurrency finance platform, was hacked by Mr. White Hat who exploited a vulnerability in its code to steal $610 million i… [+6649 chars]Grayscale Investments runs the largest cryptocurrency fund, Grayscale Bitcoin Trust.\r\nYuriko Nakao\r\nThree products from Grayscale Investments, the largest digital asset manager, that give investors e… [+1606 chars]Jerome Powell, chair of the Federal Reserve.\r\nPool/Getty Images\r\nUS stocks rebounded from last week's losses and moved higher on Monday, ahead of a key policy meeting from the Federal Reserve.\r\nFed C… [+1576 chars]Personal Finance Insider writes about products, strategies, and tips to help you make smart decisions with your money. We may receive a small commission from our partners, like American Express, but … [+4177 chars]August\r\n23, 2021\r\n2 min read\r\nPayPal announced Monday that customers in the United Kingdom will be able to buy, hold and sell cryptocurrency this week. Specifically, they can make transactions with B… [+2196 chars]Representations of cryptocurrencies Bitcoin, Ethereum, DogeCoin, Ripple, Litecoin are placed on PC motherboard in this illustration taken, June 29, 2021. REUTERS/Dado Ruvic/Illustration NEW YORK, Sep… [+2712 chars]Representations of the Ripple, Bitcoin, Etherum and Litecoin virtual currencies are seen on a PC motherboard in this illustration picture, February 13, 2018. Picture is taken February 13, 2018. WASHI… [+3787 chars]The Fine Print: The following comments are owned by whoever posted them. We are not responsible for the ...

# %%
# Run the NER processor on all of the text
doc = nlp(all_lite_text)

# Add a title to the document
doc.user_data["title"] = "Litecoin NER"

# %%
# Render the visualization
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Litecoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PayPal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will now allow users outside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to buy, hold and sell cryptocurrency for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time. The company announced
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  the launch of a new service that will allow customers in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to … [+4420 chars]PayPal is bringing the ability to buy, hold and sell cryptocurrencies across to the other side of the pond, the better part of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after it launched in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In a statement, the company said tha… [+850 chars]PayPal is to allow users in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to buy, hold and sell cryptocurrencies through the payment platform for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>The firm said it would allow customers to choose from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  types of cryptoc… [+3160 chars]PayPal launched its crypto services in the UKits
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# </br>PayPal's total payment volume reached
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $311 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Q2 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Insider Intellige
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# … [+2125 chars]Andrew
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kelly/Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>&lt;ul&gt;&lt;li&gt;Bitcoin and ether plummeted on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the same day
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  adopted the crypto as legal tender.&lt;/li&gt;&lt;li&gt;The popular cryptocurrency fell from a high of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about $52,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# … [+1835 chars]Representations of cryptocurrencies Bitcoin and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  are placed on PC motherboard in this illustration taken,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 29, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dado Ruvic/IllustrationAug 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reuters
#     <span style=

# %%
# List all Entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# PayPal ORG
# U.S. GPE
# first ORDINAL
# today DATE
# U.K. GPE
# a year DATE
# US GPE
# UK GPE
# first ORDINAL
# four CARDINAL
# first ORDINAL
# $311 billion MONEY
# Q2 2021 DATE
# Insider Intellige PERSON
# Kelly/Reuters ORG
# Tuesday DATE
# El Salvador GPE
# about $52,000 MONEY
# Ethereum PERSON
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/IllustrationAug 10 PERSON
# Reuters ORG
# +991 chars]By ORG
# Reuters ORG
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustrat PERSON
# July 14, 2021 DATE
# REUTERS ORG
# Dado Ruvic/ PERSON
# 23 CARDINAL
# Reuters ORG
# Finance Insider PERSON
# American Express ORG
# 23, 2021 DATE
# months-long DATE
# above $50,000 MONEY
# Sunday DATE
# first ORDINAL
# mid-May. DATE
# as much as 6% PERCENT
# Tuesday DATE
# Coinbase PERSON
# Monday DATE
# Poly Network ORG
# White Hat PERSON
# $610 million MONEY
# Grayscale Bitcoin Trust ORG
# Yuriko Nakao PERSON
# Three CARDINAL
# Grayscale Investments ORG
# Powell PERSON
# the Federal Reserve ORG
# US GPE
# last week's DATE
# Monday DATE
# the Federal Reserve ORG
# Finance Insider PERSON
# American Express ORG
# 23, 2021 DATE
# Monday DATE
# the United Kingdom GPE
# this week DATE
# June 29, 2021 DATE
# REUTERS ORG
# Dado Ruvic/Illustration NEW YORK ORG
# Sep ORG
# the Ripple, Bitcoin ORG
# February 13, 2018 DATE
# February 13, 2018 DATE
# WASHI ORG
# American Express ORG

# %% [markdown]
# ---
